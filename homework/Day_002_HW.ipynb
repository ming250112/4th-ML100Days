# %% [markdown]
# ## [作業目標]
# 了解機器學習適合應用的領域與範疇。

# %% [markdown]
# ## [作業重點]
# 透過瞭解機器學習的運作方式，找出非常適用機器學習應用的領域及其原因

# %% [markdown]
# ## 作業
# 請找出一個你認為機器學習可以發光發熱的領域並闡述原因?

# %%
傳統解決問題的方式是由人類將已知的規則寫成程式碼交由電腦執行，
電腦除了精確度的優勢之外卻無法比人類再更進一步，可見既有程式碼受限於人類既有知識水平．

但現今的機器學習拜硬體進步之賜，即使是狹隘的監督式學習也能讓電腦有自行摸索未知特徵與規則的能力．
這使得機器學習跳脫了人類既有知識的侷限，透過訓練就可以掌握人類未能洞察的事物．
使得電腦可能漸漸有量化未知的能力，我們覺得有神秘感的東西都將變得可分析．

2016年，運用強化學習訓練的　AlphaGO 首次在圍棋領域打敗了頂尖職業棋手．
過程中，　AlphaGO 下出了許多人類無法理解，幾經研究後卻被認定為絕佳解的 '軟手' ，
這帶領我們初窺　AlphaGO　不同於人類的取勝哲學．
這似乎暗示了冰冷的機器已經展現出比人類更加深層的洞見，正在挑戰人類引以為傲的'直覺'與'創造力'．
將我們難以理解的'創意'視為常規路數，這才是　AlphaGO 在輸贏之外真正震撼人類的地方．

基於以上理由，我認為機器學習的優勢在 '量化人類所未知' ，
只要是基於人類直覺或感知而無明確規則的領域，機器學習都可能成為領頭羊．
例如在藝術或心理領域，藉由學習人類所無法體察的特徵，
在不久的將來，電腦比我們知道什麼是'美'，比我們自己更了解自己的好惡；
因為一些'我們也說不出來'的理由，人類的行為也許會被更加精準的操控（例如：廣告能帶起更強烈的社會風潮，政令宣導更加深入人心......等等）
