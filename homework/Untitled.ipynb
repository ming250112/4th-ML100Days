# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(1,100,10000)
y = np.sin(x)
z = np.cos(x)

# %%
plt.figure(figsize=(15,5))
plt.subplot()

for i in range(2):
    plt.plot(x,np.sin(x-i)*i*0.5)
    
plt.hist(np.random.normal(size = 100),bins = 20)
# Out:
# (array([ 2.,  0.,  1.,  6.,  5.,  5.,  7.,  8.,  8.,  3., 10., 12.,  4.,
#          4.,  8.,  6.,  5.,  1.,  1.,  4.]),
#  array([-2.41728594, -2.18481093, -1.95233592, -1.71986091, -1.4873859 ,
#         -1.25491089, -1.02243589, -0.78996088, -0.55748587, -0.32501086,
#         -0.09253585,  0.13993916,  0.37241417,  0.60488917,  0.83736418,
#          1.06983919,  1.3023142 ,  1.53478921,  1.76726422,  1.99973922,
#          2.23221423]),
#  <a list of 20 Patch objects>)
